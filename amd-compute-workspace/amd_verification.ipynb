# %%
import os
from openai import OpenAI
# API Key removed for security
os.environ["FIREWORKS_API_KEY"] = "REPLACE_WITH_YOUR_KEY"

api_key = os.getenv("FIREWORKS_API_KEY")
client = OpenAI(
    base_url="https://api.fireworks.ai/inference/v1",
    api_key=api_key,
)

def verify_compute():
    print("--- AMD Compute Verification: EventNetwork AI ---")
    try:
        response = client.chat.completions.create(
            model="accounts/fireworks/models/qwen3p7-plus",
            messages=[{"role": "user", "content": "Verify connection to AMD-backed inference."}]
        )
        print("SUCCESS: Connection to Fireworks API verified.")
        print("Model Response:", response.choices[0].message.content)
    except Exception as e:
        print("ERROR: Connection failed.", str(e))

if __name__ == "__main__":
    verify_compute()
# Out:
# --- AMD Compute Verification: EventNetwork AI ---
# SUCCESS: Connection to Fireworks API verified.
# Model Response: I am Qwen, a large language model developed by Alibaba Group's Tongyi Lab. As an AI, I do not have direct visibility into or the ability to verify the specific underlying hardware infrastructure (such as AMD, NVIDIA, or custom accelerators) executing the inference at any given time. Hardware routing and deployment environments are managed by the platform's infrastructure layer.
#
# How can I assist you with your tasks or questions today?
